# %% [markdown]
# # Discussion 5

# %% [markdown]
# ## Notes

# %%
print len("abcdef") # len() is a function

print "abcdef".startswith("ab") # .startswith() is a method

# %% [markdown]
# Why can some functions be called as `foo()` directly, but others can only be called as `.foo()` on a value?
#
# The `def` keyword makes an ordinary function:

# %%
def add(x, y):
    return x + y

add(3, 6)
# Out:
# 9

# %% [markdown]
# In programming jargon, a _class_ is a formal definition of a data structure. Classes have _fields_ to store data and _methods_ to perform tasks; it makes sense to think of these as variables and functions bundled up inside the data structure.
#
# Python allows you to define your own data structures with the `class` keyword:

# %%
class Point:
    # The __init__ method is a special method that gets called when an object is created.
    def __init__(self):
        # Create fields x and y, initialized to 0.
        self.x = 0
        self.y = 0
    
    # Another method.
    def print_xy(self):
        print "({}, {})".format(self.x, self.y)
        
    def move(self, xdist, ydist):
        self.x += xdist
        self.y += ydist

# %% [markdown]
# A `def` inside of a class creates a method instead of a function.
#
# An _object_ is a specific instance of a class. You can create a new object by calling the class as if it were a function:

# %%
# Make a new Point object.
pt = Point()

# %% [markdown]
# You can use `.` to access fields and methods within an object:

# %%
pt.print_xy()
pt.move(10, -1)
pt.print_xy()
# Out:
# (0, 0)
# (10, -1)

# %% [markdown]
# You probably won't need to write your own classes this quarter. Writing classes tends to be more useful for developing applications than for data analysis.

# %% [markdown]
# ### Web APIs
#
# An _application programming interface_ (API) is a set of functions and data structures for communicating with other software. For instance, whenever you use a Python package, you're using the API created by the package's developers.
#
# Web sites sometimes provide an API so that programmers can access content without web scraping. A _representational state transfer_ (REST) API is a web API that uses different URLs for different functions. There are other kinds of web APIs, but REST APIs are popular and the easiest kind to use.
#
# Spotify provides a REST API for getting information about artists and albums, with documentation [here](https://developer.spotify.com/web-api/). All of the functions start with the base URL:
#
# ```
# https://api.spotify.com
# ```
#
# The function name and arguments are appended to the end of the base url. The function to search for an artist is at the URL:
#
# ```
# https://api.spotify.com/v1/search
# ```
#
# A _hypertext transfer protocol_ (HTTP) request to this URL searches for an artist. HTTP is also what your web browser uses to download web pages. [Several different kinds of HTTP requests are possible](https://en.wikipedia.org/wiki/Hypertext_Transfer_Protocol#Request_methods). Spotify says that the artist search function should be used with a GET request.
#
# The `requests` package has functions for making HTTP requests and is [well-documented](http://docs.python-requests.org/en/master/). Even [the Python documentation for urllib](https://docs.python.org/2/library/urllib.html) recommends using `requests` (rather than `urllib`) for most tasks.

# %%
import requests
# In terminal: conda install requests
import requests_cache
# In terminal: pip install requests_cache

# Set up a cache for requests.
requests_cache.install_cache("cache")

response = requests.get("http://jsharpna.github.io/")
# Throw an error if status isn't okay.
response.raise_for_status()

response.text # get text
response.content # get raw bytes
# Out:
# '<!DOCTYPE html>\n<!-- This page was generated by GitHub Pages using the Cayman theme by Jason Long. -->\n<html lang="en-us">\n  <head>\n    <meta charset="UTF-8">\n    <title>Sharpnack Lab</title>\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n    <link rel="stylesheet" type="text/css" href="stylesheets/normalize.css" media="screen">\n    <link href=\'https://fonts.googleapis.com/css?family=Open+Sans:400,700\' rel=\'stylesheet\' type=\'text/css\'>\n    <link rel="stylesheet" type="text/css" href="stylesheets/stylesheet.css" media="screen">\n    <link rel="stylesheet" type="text/css" href="stylesheets/github-light.css" media="screen">\n        <style type="text/css">\n      .page-header {\n      background-image:url("stylesheets/waterwise.jpg");\n      color: #fff;\n      text-shadow: 0px 0px 4px #ccccff;\n      }\n    </style>\n  </head>\n  <body>\n    <section class="page-header">\n      <h1 class="project-name">UC Davis Sharpnack Lab</h1>\n      <h2 class="project-tagline">James Sharpnack <br>Mathematical Sciences Building 4107<br>jsharpna@ucdavis.edu</h2>\n    </section>\n\n    <section class="main-content">\n      <h3>About me.</h3>\n      <div class="section group">\n\t<div class="col span_2_left">\n      <p>I am an assistant professor at UC Davis in the Statistics department. Before this I was a postdoctoral researcher and lecturer at UCSD in the Mathematics department. I hold a Ph.D in Machine Learning and Statistics from Carnegie Mellon University where my advisors were <a href="http://www.cs.cmu.edu/~aarti/">Aarti Singh</a> and <a href="http://www.stat.cmu.edu/~arinaldo/">Alessandro Rinaldo</a>.  In my research, I develop and study computationally efficient statistical methodology for understanding complex phenomena in large datasets.</p>\n\t</div>\n\t<div class="col span_2_right">\n\t  <img src="stylesheets/boardPortrait.JPG" />\n\t</div>\n      </div>\n\n<h3>Teaching</h3>\n<ol>\n  <li><a href="https://docs.google.com/document/d/15snbrjlwUYmwj4voSA_33qqtMxHrYXKlhnElGK1dPC0/edit?usp=sharing">Stats 290</a>: Statistics Seminar Series</li>\n  <li><a href="141B/index.html">Stats 141B</a>: Data & Web Technologies for Data Analysis</li>\n  <li><a href="208/index.html">Stats 208</a>: Machine Learning</li>\n</ol>\n\n<h3>Students</h3>\n<ol>\n  <li>Liwei Wu, PhD Student</li>\n  <li>Xiaoyue Li, PhD Student</li>\n  <li>Yujun Chen, Masters Student</li>\n  <li>Andrew Chin, Undergraduate Student</li>\n</ol>\n\n<h3>Professional Membership</h3>\n<ol>\n  <li>Institute of Mathematical Statistics</li>\n  <li>Bernoulli Society</li>\n  <li>IEEE, Signal Processing Society</li>\n</ol>\n\n<h3>Research</h3>\n\n<div class="pubsec section group">\n<div class="col span_half">\n  <a href="research/graphsignal.html"><img src="media/As_slide.png" type="application/pdf"></img></a>\n</div>\n<div class="col span_half">\n  <a href="research/graphsignal.html"><h4>Graph Structured Signal Processing</h4>\n  (6 publications)<br></a>\n  Traditional signal processing techniques such as wavelet denoising and kernel smoothing, implicitly assume that the domain is homogeneous.  Graph structure provides us with a more flexible framework for filters over heterogeneous media, social networks, or semantic information.\n</div>\n</div>\n\n<div class="pubsec section group">\n<div class="col span_half">\n  <a href="research/scan.html"><h4>Scan Statistics over Networks</h4>\n    (6 publications)<br></a>\n    We develop novel methodology for detecting faint signals in sensor networks and images.\n  In images we develop a precise asymptotic analysis for fast scanning tools based on convolutional feedforward neural nets.\n  In general graphs, we look at approximation algorithms for the generalized likelihood ratio test.\n</div>\n<div class="col span_half">\n  <a href="research/scan.html"><img width="60%" src="media/graphscan.png" type="application/pdf"></img></a>\n</div>\n</div>\n\n<div class="pubsec section group">\n<div class="col span_half">\ ...

# %% [markdown]
# Let's write a Python function that acts as a wrapper for Spotify's search function.

# %%
def spotify_search(term, search_type = "artist", verbose = False):
    url = "https://api.spotify.com/v1/search"
    response = requests.get(url, params = {
        "q": term,
        "type": search_type
    })
    response.raise_for_status() # check for errors
    if verbose:
        print response.url

    return response.json() # parse JSON

# %% [markdown]
# Most of the time, it's a good strategy to "wrap" each web API fuction with a Python function. This lets you to use the web API as if it's just another Python module.
#
# If you're using the web API to get data, the next step is to convert the data to a Pandas data frame:

# %%
import pandas as pd
artists = ("sgagegehffb", "Lady Gaga", "Migos", "Taylor Swift", "Slayer", "Radiohead", "Mr. Bungle", "Tame Impala", "Queen")

#results = [spotify_search(x)["artists"]["items"] for x in artists]
def search_artist(artist):
    items = spotify_search(artist, verbose = False)["artists"]["items"]
    # Check whether there were any search results.
    if len(items) == 0:
        # No results, so return the only data we have.
        return {"name": artist}
    
    return items[0]
  
# Build a data frame from a list of dicts.
pd.DataFrame([search_artist(x) for x in artists])
# Out:
#                                        external_urls  \
# 0                                                NaN
# 1  {u'spotify': u'https://open.spotify.com/artist...
# 2  {u'spotify': u'https://open.spotify.com/artist...
# 3  {u'spotify': u'https://open.spotify.com/artist...
# 4  {u'spotify': u'https://open.spotify.com/artist...
# 5  {u'spotify': u'https://open.spotify.com/artist...
# 6  {u'spotify': u'https://open.spotify.com/artist...
# 7  {u'spotify': u'https://open.spotify.com/artist...
# 8  {u'spotify': u'https://open.spotify.com/artist...
#
#                             followers  \
# 0                                 NaN
# 1  {u'total': 2418347, u'href': None}
# 2   {u'total': 735403, u'href': None}
# 3  {u'total': 5019778, u'href': None}
# 4   {u'total': 505119, u'href': None}
# 5  {u'total': 1954780, u'href': None}
# 6    {u'total': 46726, u'href': None}
# 7  {u'total': 1064763, u'href': None}
# 8  {u'total': 3181223, u'href': None}
#
#                                               genres  \
# 0                                                NaN
# 1     [dance pop, pop, pop christmas, post-teen pop]
# 2               [dwn trap, pop rap, rap, trap music]
# 3     [dance pop, pop, pop christmas, post-teen pop]
# 4  [alternative metal, death metal, groove metal,...
# 5  [alternative rock, indie rock, melancholia, pe...
# 6  [alternative metal, experimental rock, funk me...
# 7  [australian alternative rock, indie pop, indie...
# 8  [album rock, classic rock, glam rock, hard roc...
#
#                                                 href                      id  \
# 0                                                NaN                     NaN
# 1  https://api.spotify.com/v1/artists/1HY2Jd0NmPu...  1HY2Jd0NmPuamShAr6KMms
# 2  https://api.spotify.com/v1/artists/6oMuImdp5Zc...  6oMuImdp5ZcFhWP0ESe6mG
# 3  https://api.spotify.com/v1/artists/06HL4z0CvFA...  06HL4z0CvFAxyc27GXpf02
# 4  https://api.spotify.com/v1/artists/1IQ2e1buppa...  1IQ2e1buppatiN1bxUVkrk
# 5  https://api.spotify.com/v1/artists/4Z8W4fKeB5Y...  4Z8W4fKeB5YxbusRsdQVPb
# 6  https://api.spotify.com/v1/artists/2zq0uqN9Wq1...  2zq0uqN9Wq12tqrQQt1ozw
# 7  https://api.spotify.com/v1/artists/5INjqkS1o8h...  5INjqkS1o8h1imAzPqGZBb
# 8  https://api.spotify.com/v1/artists/1dfeR4HaWDb...  1dfeR4HaWDbWqFHLkxsg1d
#
#                                               images          name  \
# 0                                                NaN   sgagegehffb
# 1  [{u'url': u'https://i.scdn.co/image/c2e26db97f...     Lady Gaga
# 2  [{u'url': u'https://i.scdn.co/image/6f77fdcfcb...         Migos
# 3  [{u'url': u'https://i.scdn.co/image/8e985a4c3a...  Taylor Swift
# 4  [{u'url': u'https://i.scdn.co/image/8c81130db7...        Slayer
# 5  [{u'url': u'https://i.scdn.co/image/afcd616e1e...     Radiohead
# 6  [{u'url': u'https://i.scdn.co/image/f108bec8a5...    Mr. Bungle
# 7  [{u'url': u'https://i.scdn.co/image/11ea8d2291...   Tame Impala
# 8  [{u'url': u'https://i.scdn.co/image/b040846ceb...         Queen
#
#    popularity    type                                    uri
# 0         NaN     NaN                                    NaN
# 1        86.0  artist  spotify:artist:1HY2Jd0NmPuamShAr6KMms
# 2        92.0  artist  spotify:artist:6oMuImdp5ZcFhWP0ESe6mG
# 3        87.0  artist  spotify:artist:06HL4z0CvFAxyc27GXpf02
# 4        67.0  artist  spotify:artist:1IQ2e1buppatiN1bxUVkrk
# 5        80.0  artist  spotify:artist:4Z8W4fKeB5YxbusRsdQVPb
# 6        44.0  artist  spotify:artist:2zq0uqN9Wq12tqrQQt1ozw
# 7        78.0  artist  spotify:artist:5INjqkS1o8h1imAzPqGZBb
# 8        83.0  artist  spotify:artist:1dfeR4HaWDbWqFHLkxsg1d

# %% [markdown]
# Now let's write a function that wraps Spotify's album list function.

# %%
def spotify_albums(artist_id):
    url = "https://api.spotify.com/v1/artists/{id}/albums".format(id = artist_id)
    response = requests.get(url, params = {
        "album_type": "album",
        "market": "US"
    })
    response.raise_for_status()

    return response.json()

# %%
spotify_albums("1dfeR4HaWDbWqFHLkxsg1d") # Queen
# Out:
# {u'href': u'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d/albums?offset=0&limit=20&album_type=album&market=US',
#  u'items': [{u'album_type': u'album',
#    u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      u'href': u'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      u'id': u'1dfeR4HaWDbWqFHLkxsg1d',
#      u'name': u'Queen',
#      u'type': u'artist',
#      u'uri': u'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    u'available_markets': [u'CA', u'US'],
#    u'external_urls': {u'spotify': u'https://open.spotify.com/album/60TXSuzXQoEy3p5cQEkLu7'},
#    u'href': u'https://api.spotify.com/v1/albums/60TXSuzXQoEy3p5cQEkLu7',
#    u'id': u'60TXSuzXQoEy3p5cQEkLu7',
#    u'images': [{u'height': 640,
#      u'url': u'https://i.scdn.co/image/83bc8d97de6e16e901409ea9a9d18982bac472e7',
#      u'width': 640},
#     {u'height': 300,
#      u'url': u'https://i.scdn.co/image/f6ee3edced72f92be8c947cd0d149b5a89d15d21',
#      u'width': 300},
#     {u'height': 64,
#      u'url': u'https://i.scdn.co/image/387d80b6397bc8c815b0f828931d49e2c508fa0a',
#      u'width': 64}],
#    u'name': u'Queen On Air',
#    u'type': u'album',
#    u'uri': u'spotify:album:60TXSuzXQoEy3p5cQEkLu7'},
#   {u'album_type': u'album',
#    u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      u'href': u'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      u'id': u'1dfeR4HaWDbWqFHLkxsg1d',
#      u'name': u'Queen',
#      u'type': u'artist',
#      u'uri': u'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    u'available_markets': [u'CA', u'US'],
#    u'external_urls': {u'spotify': u'https://open.spotify.com/album/03fubwn4664emOoK7WkOdK'},
#    u'href': u'https://api.spotify.com/v1/albums/03fubwn4664emOoK7WkOdK',
#    u'id': u'03fubwn4664emOoK7WkOdK',
#    u'images': [{u'height': 640,
#      u'url': u'https://i.scdn.co/image/bf70df6d70c50b6e1e5fd33aaf0583d02c48cccb',
#      u'width': 640},
#     {u'height': 300,
#      u'url': u'https://i.scdn.co/image/3746ae4d04e36406b05a5de5a41b21a2f3213afd',
#      u'width': 300},
#     {u'height': 64,
#      u'url': u'https://i.scdn.co/image/095d89e97817e218000182a5f2e9c6f571ac883f',
#      u'width': 64}],
#    u'name': u'A Night at the Odeon',
#    u'type': u'album',
#    u'uri': u'spotify:album:03fubwn4664emOoK7WkOdK'},
#   {u'album_type': u'album',
#    u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      u'href': u'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      u'id': u'1dfeR4HaWDbWqFHLkxsg1d',
#      u'name': u'Queen',
#      u'type': u'artist',
#      u'uri': u'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    u'available_markets': [u'CA', u'US'],
#    u'external_urls': {u'spotify': u'https://open.spotify.com/album/5wTdQlDnvBtUO3ptbwqeyz'},
#    u'href': u'https://api.spotify.com/v1/albums/5wTdQlDnvBtUO3ptbwqeyz',
#    u'id': u'5wTdQlDnvBtUO3ptbwqeyz',
#    u'images': [{u'height': 640,
#      u'url': u'https://i.scdn.co/image/3b746617c571fd922e51cbcc24ca80ddf8946da9',
#      u'width': 640},
#     {u'height': 300,
#      u'url': u'https://i.scdn.co/image/90ee1b748147ed936c81aab9b316f827715721cf',
#      u'width': 300},
#     {u'height': 64,
#      u'url': u'https://i.scdn.co/image/adbcc2563cc8214c5fed4c5b67276a8e5468d510',
#      u'width': 64}],
#    u'name': u'Live at the Rainbow \u201874',
#    u'type': u'album',
#    u'uri': u'spotify:album:5wTdQlDnvBtUO3ptbwqeyz'},
#   {u'album_type': u'album',
#    u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      u'href': u'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      u'id': u'1dfeR4HaWDbWqFHLkxsg1d',
#      u'name': u'Queen',
#      u'type': u'artist',
#      u'uri': u'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    u'available_markets': [u'US'],
#    u'external_urls': {u'spotify': u'https://open.spotify.com/album/2IY3Ty8CrUyvpibt8AcZmp'},
#    u'href': u'https://api.spotify.com/v1/albums/2IY3Ty8CrUyvpibt8AcZmp',
#    u'id': u'2IY3Ty8CrUyvpibt8AcZmp',
#    u'images': [{u'height': 634,
#      u'url': u'https://i.scdn.co/image/b013176f817dbddf874f29551dfa0febed5fa228',
#      u'width': 640},
#     {u'height': 297,
#      u'url': u'https://i.scdn.co/image/cf1c12cd3f7351cc07207e23eeb11bce00862c7e',
#      u'width': 300},
#     {u'height': 63,
#      u'url': u'https://i.scdn.co/image/a4f0d81a4c29dc55d887025e2ae1f38043f24a93',
#      u'width': 64}],
#    u'name': u'Queen Rock Montreal',
#    u'type': u'album',
#    u'uri': u'spotify:album:2IY3Ty8CrUyvpibt8AcZmp'},
#   {u'album_type': u'album',
#    u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      u'href': u'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      u'id': u'1dfeR4HaWDbWqFHLkxsg1d',
#      u'name': u'Queen',
#      u'type': u'artist',
#      u'uri': u'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    u'available_markets': [u'CA', u'US'],
#    u'external_urls': {u'spotify': u'https://open.spotify.com/album/2SFIh6siY4KYBNPHAV7xaI'},
#    u'href': u'https://api.spotify.com/v1/albums/2SFIh6siY4KYBNPHAV7xaI',
#    u'id': u'2SFIh6siY4KYBNPHAV7xaI',
#    u'images': [{u'height': 640,
#      u'url': u'https://i.scdn.co/image/fcf31d9b72a643df29d8e65cc8cb0e4566ff2420',
#      u'width': 640},
#     {u'height': 300,
#      u'url': u'https://i.scdn.co/image/7a97318e63bc407113b1451a7f015a2d17e2d953',
#      u'width': 300},
#     {u'height': 64,
#      u'url': u'https://i.scdn.co/image/62a6f57ddf45df697c39d02f594eb2cadeea41b4',
#      u'width': 64}],
#    u'name': u'Made In Heaven',
#    u'type': u'album',
#    u'uri': u'spotify:album:2SFIh6siY4KYBNPHAV7xaI'},
#   {u'album_type': u'album',
#    u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      u'href': u'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      u'id': u'1dfeR4HaWDbWqFHLkxsg1d',
#      u'name': u'Queen',
#      u'type': u'artist',
#      u'uri': u'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    u'available_markets': [u'CA', u'US'],
#    u'external_urls': {u'spotify': u'https://open.spotify.com/album/4fODEKBcruDGTihYHvBXBD'},
#    u'href': u'https://api.spotify.com/v1/albums/4fODEKBcruDGTihYHvBXBD',
#    u'id': u'4fODEKBcruDGTihYHvBXBD',
#    u'images': [{u'height': 640,
#      u'url': u'https://i.scdn.co/image/4914ffb4d85d2c2118cad31f4087aa94f5107108',
#      u'width': 640},
#     {u'height': 300,
#      u'url': u'https://i.scdn.co/image/fb78a9f67229e7369a5c3e22c4e80a1dadf0b12f',
#      u'width': 300},
#     {u'height': 64,
#      u'url': u'https://i.scdn.co/image/01cbbdee35cfaf3041b633f7fef7e86260ce1db3',
#      u'width': 64}],
#    u'name': u'Made in Heaven (Deluxe Remastered Version)',
#    u'type': u'album',
#    u'uri': u'spotify:album:4fODEKBcruDGTihYHvBXBD'},
#   {u'album_type': u'album',
#    u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      u'href': u'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      u'id': u'1dfeR4HaWDbWqFHLkxsg1d',
#      u'name': u'Queen',
#      u'type': u'artist',
#      u'uri': u'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    u'available_markets': [u'CA', u'US'],
#    u'external_urls': {u'spotify': u'https://open.spotify.com/album/3uk2r2tVRHy9L15rHJhD2S'},
#    u'href': u'https://api.spotify.com/v1/albums/3uk2r2tVRHy9L15rHJhD2S',
#    u'id': u'3uk2r2tVRHy9L15rHJhD2S',
#    u'images': [{u'height': 640,
#      u'url': u'https://i.scdn.co/image/4cce517772187ab874a0ea349566d86aeab539eb',
#      u'width': 627},
#     {u'height': 300,
#      u'url': u'https://i.scdn.co/image/3f3f67a8adab42f847a2edbc0f0cc683f84355ff',
#      u'width': 294},
#     {u'height': 64,
#      u'url': u'https://i.scdn.co/image/9c4f6208745623d59d0af36ecb5954d43cc502ae',
#      u'width': 63}],
#    u'name': u'Live At Wembley Stadium',
#    u'type': u'album',
#    u'uri': u'spotify:album:3uk2r2tVRHy9L15rHJhD2S'},
#   {u'album_type': u'album',
#    u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      u'href': u'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      u'id': u'1dfeR4HaWDbWqFHLkxsg1d',
#      u'name': u'Queen',
#      u'type': u'artist',
#      u'uri': u'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    u'available_markets': [u'CA', u'US'],
#    u'external_urls': {u'spotify': u'https://open.spotify.com/album/5yAM3CcaXF6DPRJW3oL6Ya'},
#    u'href': u'https://api.spotify.com/v1/albums/5yAM3CcaXF6DPRJW3oL6Ya',
#    u'id': u'5yAM3CcaXF6DPRJW3oL6Ya',
#    u'images': [{u'height': 640,
#      u'url': u'https://i.scdn.co/image/15c36bab75a4a19e2fe8f3618705cea10e25d0fb',
#      u'width': 640},
#     {u'height': 300,
#      u'url': u'https://i.scdn.co/image/ab82059165689a302f2d8b4447015cfb4adb689b',
#      u'width': 300},
#     {u'height': 64,
#      u'url': u'https://i.scdn.co/image/68a220cd74ad600fc8b57ef44718eed19cc4b224',
#      u'width': 64}],
#    u'name': u'Innuendo',
#    u'type': u'album',
#    u'uri': u'spotify:album:5yAM3CcaXF6DPRJW3oL6Ya'},
#   {u'album_type': u'album',
#    u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      u'href': u'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      u'id': u'1dfeR4HaWDbWqFHLkxsg1d',
#      u'name': u'Queen',
#      u'type': u'artist',
#      u'uri': u'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    u'available_markets': [u'CA', u'US'],
#    u'external_urls': {u'spotify': u'https://open.spotify.com/album/2LC6PPb29hs8rkPHBjUVXJ'},
#    u'href': u'https://api.spotify.com/v1/albums/2LC6PPb29hs8rkPHBjUVXJ',
#    u'id': u'2LC6PPb29hs8rkPHBjUVXJ',
#    u'images': [{u'height': 640,
#      u'url': u'https://i.scdn.co/image/253bc2b564226602a163125a9751d97d601a334d',
#      u'width': 640},
#     {u'height': 300,
#      u'url': u'https://i.scdn.co/image/3643b14a4b0d4f1d90392c08de7a193bd617ce60',
#      u'width': 300},
#     {u'height': 64,
#      u'url': u'https://i.scdn.co/image/687a93688ddbede5059635990d2303ce7ebba252',
#      u'width': 64}],
#    u'name': u'Innuendo (Deluxe Remastered Version)',
#    u'type': u'album',
#    u'uri': u'spotify:album:2LC6PPb29hs8rkPHBjUVXJ'},
#   {u'album_type': u'album',
#    u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      u'href': u'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      u'id': u'1dfeR4HaWDbWqFHLkxsg1d',
#      u'name': u'Queen',
#      u'type': u'artist',
#      u'uri': u'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    u'available_markets': [u'CA', u'US'],
#    u'external_urls': {u'spotify': u'https://open.spotify.com/album/1v5l2sZRE5Rweew5PoNFP9'},
#    u'href': u'https://api.spotify.com/v1/albums/1v5l2sZRE5Rweew5PoNFP9',
#    u'id': u'1v5l2sZRE5Rweew5PoNFP9',
#    u'images': [{u'height': 640,
#      u'url': u'https://i.scdn.co/image/eba8ec2cb42c919178d4a22c97532963a6905d16',
#      u'width': 640},
#     {u'height': 300,
#      u'url': u'https://i.scdn.co/image/78296287c463f94d0f11e1b80bd260969bf6372f',
#      u'width': 300},
#     {u'height': 64,
#      u'url': u'https://i.scdn.co/image/b804d5afaa9b2cfcab8af2c2b71a29f5298e9774',
#      u'width': 64}],
#    u'name': u'The Miracle',
#    u'type': u'album',
#    u'uri': u'spotify:album:1v5l2sZRE5Rweew5PoNFP9'},
#   {u'album_type': u'album',
#    u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      u'href': u'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      u'id': u'1dfeR4HaWDbWqFHLkxsg1d',
#      u'name': u'Queen',
#      u'type': u'artist',
#      u'uri': u'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    u'available_markets': [u'CA', u'US'],
#    u'external_urls': {u'spotify': u'https://open.spotify.com/album/0kCPII9EM5eqHHCRo1EVjs'},
#    u'href': u'https://api.spotify.com/v1/albums/0kCPII9EM5eqHHCRo1EVjs',
#    u'id': u'0kCPII9EM5eqHHCRo1EVjs',
#    u'images': [{u'height': 640,
#      u'url': u'https://i.scdn.co/image/3e25217229ef190a2aeb2f94370a1d82d8913d56',
#      u'width': 640},
#     {u'height': 300,
#      u'url': u'https://i.scdn.co/image/1436b499c78561bceef62500ffc706d416384641',
#      u'width': 300},
#     {u'height': 64,
#      u'url': u'https://i.scdn.co/image/86592cfd14247fdcf3cff52e02aa467a67cf005b',
#      u'width': 64}],
#    u'name': u'The Miracle (Deluxe Remastered Version)',
#    u'type': u'album',
#    u'uri': u'spotify:album:0kCPII9EM5eqHHCRo1EVjs'},
#   {u'album_type': u'album',
#    u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      u'href': u'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      u'id': u'1dfeR4HaWDbWqFHLkxsg1d',
#      u'name': u'Queen',
#      u'type': u'artist',
#      u'uri': u'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    u'available_markets': [u'CA', u'US'],
#    u'external_urls': {u'spotify': u'https://open.spotify.com/album/6QYnikkyKvjmFtTiZVeCW7'},
#    u'href': u'https://api.spotify.com/v1/albums/6QYnikkyKvjmFtTiZVeCW7',
#    u'id': u'6QYnikkyKvjmFtTiZVeCW7',
#    u'images': [{u'height': 640,
#      u'url': u'https://i.scdn.co/image/289b522b00cf3909b16cd4d84293fdcc644d0927',
#      u'width': 640},
#     {u'height': 300,
#      u'url': u'https://i.scdn.co/image/2bf923698c47c8ba9286149901d6a8cdc8bf91f7',
#      u'width': 300},
#     {u'height': 64,
#      u'url': u'https://i.scdn.co/image/5f813f7b9ed24fea43353b758b17ad26e2ec8b32',
#      u'width': 64}],
#    u'name': u'A Kind of Magic (Deluxe Remastered Version)',
#    u'type': u'album',
#    u'uri': u'spotify:album:6QYnikkyKvjmFtTiZVeCW7'},
#   {u'album_type': u'album',
#    u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      u'href': u'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      u'id': u'1dfeR4HaWDbWqFHLkxsg1d',
#      u'name': u'Queen',
#      u'type': u'artist',
#      u'uri': u'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    u'available_markets': [u'CA', u'US'],
#    u'external_urls': {u'spotify': u'https://open.spotify.com/album/34xBXeJgmQrn1wQvhyVCsw'},
#    u'href': u'https://api.spotify.com/v1/albums/34xBXeJgmQrn1wQvhyVCsw',
#    u'id': u'34xBXeJgmQrn1wQvhyVCsw',
#    u'images': [{u'height': 640,
#      u'url': u'https://i.scdn.co/image/2bcbcb6c74044152dd36d13929cfeaa70ec520d0',
#      u'width': 640},
#     {u'height': 300,
#      u'url': u'https://i.scdn.co/image/341b4d2702b7ad6351b70ce591673be7ea3ce93d',
#      u'width': 300},
#     {u'height': 64,
#      u'url': u'https://i.scdn.co/image/2d126012c81f33fbbaf8991f6d51fc646ef55aae',
#      u'width': 64}],
#    u'name': u'A Kind Of Magic',
#    u'type': u'album',
#    u'uri': u'spotify:album:34xBXeJgmQrn1wQvhyVCsw'},
#   {u'album_type': u'album',
#    u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      u'href': u'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      u'id': u'1dfeR4HaWDbWqFHLkxsg1d',
#      u'name': u'Queen',
#      u'type': u'artist',
#      u'uri': u'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    u'available_markets': [u'CA', u'US'],
#    u'external_urls': {u'spotify': u'https://open.spotify.com/album/0FbnXAGmgmWBmNthZSgm43'},
#    u'href': u'https://api.spotify.com/v1/albums/0FbnXAGmgmWBmNthZSgm43',
#    u'id': u'0FbnXAGmgmWBmNthZSgm43',
#    u'images': [{u'height': 640,
#      u'url': u'https://i.scdn.co/image/73101a6c923d3fb6cba6296955a39cf9492942e9',
#      u'width': 640},
#     {u'height': 300,
#      u'url': u'https://i.scdn.co/image/97c70c6e88d767da1354f75b5844e91c43d799c5',
#      u'width': 300},
#     {u'height': 64,
#      u'url': u'https://i.scdn.co/image/0415a759118024cfbc9cbdff17a5a0878390eaa7',
#      u'width': 64}],
#    u'name': u'The Works',
#    u'type': u'album',
#    u'uri': u'spotify:album:0FbnXAGmgmWBmNthZSgm43'},
#   {u'album_type': u'album',
#    u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      u'href': u'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      u'id': u'1dfeR4HaWDbWqFHLkxsg1d',
#      u'name': u'Queen',
#      u'type': u'artist',
#      u'uri': u'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    u'available_markets': [u'CA', u'US'],
#    u'external_urls': {u'spotify': u'https://open.spotify.com/album/7oHaj9jkWHByziQsqGAb8V'},
#    u'href': u'https://api.spotify.com/v1/albums/7oHaj9jkWHByziQsqGAb8V',
#    u'id': u'7oHaj9jkWHByziQsqGAb8V',
#    u'images': [{u'height': 640,
#      u'url': u'https://i.scdn.co/image/6bd26952895dacf25b7529e58b2f118e61d42226',
#      u'width': 640},
#     {u'height': 300,
#      u'url': u'https://i.scdn.co/image/be6434a26cf7984b47979f89d26c54dc4796a0a0',
#      u'width': 300},
#     {u'height': 64,
#      u'url': u'https://i.scdn.co/image/45e552a7b9f774015de2abe8b4b877bd34ec2727',
#      u'width': 64}],
#    u'name': u'The Works (Deluxe Remastered Version)',
#    u'type': u'album',
#    u'uri': u'spotify:album:7oHaj9jkWHByziQsqGAb8V'},
#   {u'album_type': u'album',
#    u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      u'href': u'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      u'id': u'1dfeR4HaWDbWqFHLkxsg1d',
#      u'name': u'Queen',
#      u'type': u'artist',
#      u'uri': u'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    u'available_markets': [u'CA', u'US'],
#    u'external_urls': {u'spotify': u'https://open.spotify.com/album/0xc5IpJM39eEEYSKDrm5kf'},
#    u'href': u'https://api.spotify.com/v1/albums/0xc5IpJM39eEEYSKDrm5kf',
#    u'id': u'0xc5IpJM39eEEYSKDrm5kf',
#    u'images': [{u'height': 640,
#      u'url': u'https://i.scdn.co/image/140a81a2d5930b281f6ce32d2e673461c5473718',
#      u'width': 640},
#     {u'height': 300,
#      u'url': u'https://i.scdn.co/image/71fd1290898ec33dff419241bef0b26f3404d414',
#      u'width': 300},
#     {u'height': 64,
#      u'url': u'https://i.scdn.co/image/4b55d00b34d59bca91b11592c44af6566975156c',
#      u'width': 64}],
#    u'name': u'Hot Space (Deluxe Remastered Version)',
#    u'type': u'album',
#    u'uri': u'spotify:album:0xc5IpJM39eEEYSKDrm5kf'},
#   {u'album_type': u'album',
#    u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      u'href': u'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      u'id': u'1dfeR4HaWDbWqFHLkxsg1d',
#      u'name': u'Queen',
#      u'type': u'artist',
#      u'uri': u'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    u'available_markets': [u'CA', u'US'],
#    u'external_urls': {u'spotify': u'https://open.spotify.com/album/0JCLXuGXJ7lKKOD5mc1Ela'},
#    u'href': u'https://api.spotify.com/v1/albums/0JCLXuGXJ7lKKOD5mc1Ela',
#    u'id': u'0JCLXuGXJ7lKKOD5mc1Ela',
#    u'images': [{u'height': 640,
#      u'url': u'https://i.scdn.co/image/15dee68a9ef74706e8508e5ebafd16eaa3b618e8',
#      u'width': 640},
#     {u'height': 300,
#      u'url': u'https://i.scdn.co/image/e2781a0e6abf81d3b3b9233f0eae6bdbd95aab9f',
#      u'width': 300},
#     {u'height': 64,
#      u'url': u'https://i.scdn.co/image/4f3f7d8acc078268a8ad89ecb3a3db04ab13ba93',
#      u'width': 64}],
#    u'name': u'Flash Gordon (Deluxe Remastered Version)',
#    u'type': u'album',
#    u'uri': u'spotify:album:0JCLXuGXJ7lKKOD5mc1Ela'},
#   {u'album_type': u'album',
#    u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      u'href': u'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      u'id': u'1dfeR4HaWDbWqFHLkxsg1d',
#      u'name': u'Queen',
#      u'type': u'artist',
#      u'uri': u'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    u'available_markets': [u'CA', u'US'],
#    u'external_urls': {u'spotify': u'https://open.spotify.com/album/6wPXUmYJ9mOWrKlLzZ5cCa'},
#    u'href': u'https://api.spotify.com/v1/albums/6wPXUmYJ9mOWrKlLzZ5cCa',
#    u'id': u'6wPXUmYJ9mOWrKlLzZ5cCa',
#    u'images': [{u'height': 640,
#      u'url': u'https://i.scdn.co/image/f06d523c99007852e102967846374a0ed91c04c7',
#      u'width': 640},
#     {u'height': 300,
#      u'url': u'https://i.scdn.co/image/386059b9eef628dea849170d67dee7b5cfb18cf2',
#      u'width': 300},
#     {u'height': 64,
#      u'url': u'https://i.scdn.co/image/f821ee81a8ee95cb2aad4e51da78d7e85d859410',
#      u'width': 64}],
#    u'name': u'The Game (Deluxe Remastered Version)',
#    u'type': u'album',
#    u'uri': u'spotify:album:6wPXUmYJ9mOWrKlLzZ5cCa'},
#   {u'album_type': u'album',
#    u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      u'href': u'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      u'id': u'1dfeR4HaWDbWqFHLkxsg1d',
#      u'name': u'Queen',
#      u'type': u'artist',
#      u'uri': u'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    u'available_markets': [u'US'],
#    u'external_urls': {u'spotify': u'https://open.spotify.com/album/4c5Olye77P5ii9DEG7UlZX'},
#    u'href': u'https://api.spotify.com/v1/albums/4c5Olye77P5ii9DEG7UlZX',
#    u'id': u'4c5Olye77P5ii9DEG7UlZX',
#    u'images': [{u'height': 640,
#      u'url': u'https://i.scdn.co/image/0dbebeb5671c869759d4b57e58c5fececc2a2949',
#      u'width': 640},
#     {u'height': 300,
#      u'url': u'https://i.scdn.co/image/f1f577b49456de203173987f7dd9356a0a198f1d',
#      u'width': 300},
#     {u'height': 64,
#      u'url': u'https://i.scdn.co/image/7db48a28e2f04f8f50dd66e2ea053c6d1c4f8caa',
#      u'width': 64}],
#    u'name': u'Live Killers',
#    u'type': u'album',
#    u'uri': u'spotify:album:4c5Olye77P5ii9DEG7UlZX'},
#   {u'album_type': u'album',
#    u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      u'href': u'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      u'id': u'1dfeR4HaWDbWqFHLkxsg1d',
#      u'name': u'Queen',
#      u'type': u'artist',
#      u'uri': u'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    u'available_markets': [u'CA', u'US'],
#    u'external_urls': {u'spotify': u'https://open.spotify.com/album/5X3rA8To5GDOeIWdQyMEcE'},
#    u'href': u'https://api.spotify.com/v1/albums/5X3rA8To5GDOeIWdQyMEcE',
#    u'id': u'5X3rA8To5GDOeIWdQyMEcE',
#    u'images': [{u'height': 640,
#      u'url': u'https://i.scdn.co/image/264de0719e3f774beb9006fdfc9574465c959798',
#      u'width': 640},
#     {u'height': 300,
#      u'url': u'https://i.scdn.co/image/71a1161bbd06d09ce9ec0c67d9f5f738b8b5565e',
#      u'width': 300},
#     {u'height': 64,
#      u'url': u'https://i.scdn.co/image/c96e50f76c8bd01af7e1c394e25d1ca411bb7726',
#      u'width': 64}],
#    u'name': u'Jazz',
#    u'type': u'album',
#    u'uri': u'spotify:album:5X3rA8To5GDOeIWdQyMEcE'}],
#  u'limit': 20,
#  u'next': u'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d/albums?offset=20&limit=20&album_type=album&market=US',
#  u'offset': 0,
#  u'previous': None,
#  u'total': 33}

# %% [markdown]
# Next week we'll look at how to merge the album data into the artists data frame (in the first 10 minutes), and then I'll take questions.
