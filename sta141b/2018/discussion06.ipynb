# %% [markdown]
# # Week 6 Discussion
#
# ## Infographic
#
# * [Can't Trust Nutrition](http://fivethirtyeight.com/features/you-cant-trust-what-you-read-about-nutrition/)
#
# ## Links
#
# ## Notes

# %% [markdown]
# #### Hypertext Transfer Protocol
#
# The hypertext transfer protocol (HTTP) is a set of rules for communication on the web.
#
# For example, your web browser (Firefox, Chrome, Edge, ...) uses HTTP every time you visit a web page. The browser makes a _request_ to the server for the page, and if nothing goes wrong, the server responds with the page.
#
# Several [different kinds of HTTP requests](https://en.wikipedia.org/wiki/Hypertext_Transfer_Protocol#Request_methods) are possible. Think of these as the different "verbs" you can be use when communicating in HTTP.
#
# The `requests` package has functions for making HTTP requests from Python and is [well-documented](http://docs.python-requests.org/en/master/). Even [the Python documentation for urllib](https://docs.python.org/2/library/urllib.html) recommends using `requests` (rather than `urllib`) for most tasks.

# %%
import requests

response = requests.get("https://jsharpna.github.io/")

# %%
response.status_code
# Out:
# 200

# %%
response.raise_for_status() # throw an error/exception if status code is 4xx or 5xx

# %%
response.text

# Lots of < usually means HTML/XML
# Lots of [, { usually means JSON
# Out:
# '<!DOCTYPE html>\n<!-- This page was generated by GitHub Pages using the Cayman theme by Jason Long. -->\n<html lang="en-us">\n  <head>\n    <meta charset="UTF-8">\n    <title>Sharpnack Lab</title>\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n    <link rel="stylesheet" type="text/css" href="stylesheets/normalize.css" media="screen">\n    <link href=\'https://fonts.googleapis.com/css?family=Open+Sans:400,700\' rel=\'stylesheet\' type=\'text/css\'>\n    <link rel="stylesheet" type="text/css" href="stylesheets/stylesheet.css" media="screen">\n    <link rel="stylesheet" type="text/css" href="stylesheets/github-light.css" media="screen">\n        <style type="text/css">\n      .page-header {\n      background-image:url("stylesheets/waterwise.jpg");\n      color: #fff;\n      text-shadow: 0px 0px 4px #ccccff;\n      }\n    </style>\n  </head>\n  <body>\n    <section class="page-header">\n      <h1 class="project-name">UC Davis Sharpnack Lab</h1>\n      <h2 class="project-tagline">James Sharpnack <br>Mathematical Sciences Building 4107<br>jsharpna@ucdavis.edu</h2>\n    </section>\n\n    <section class="main-content">\n      <h3>About me.</h3>\n      <div class="section group">\n\t<div class="col span_2_left">\n      <p>I am an assistant professor at UC Davis in the Statistics department. Before this I was a postdoctoral researcher and lecturer at UCSD in the Mathematics department. I hold a Ph.D in Machine Learning and Statistics from Carnegie Mellon University where my advisors were <a href="http://www.cs.cmu.edu/~aarti/">Aarti Singh</a> and <a href="http://www.stat.cmu.edu/~arinaldo/">Alessandro Rinaldo</a>.  In my research, I develop and study computationally efficient statistical methodology for understanding complex phenomena in large datasets.</p>\n\t</div>\n\t<div class="col span_2_right">\n\t  <img src="stylesheets/boardPortrait.JPG" />\n\t</div>\n      </div>\n\n<h3>Teaching</h3>\n<ol>\n  <li><a href="https://docs.google.com/document/d/15snbrjlwUYmwj4voSA_33qqtMxHrYXKlhnElGK1dPC0/edit?usp=sharing">Stats 290</a>: Statistics Seminar Series</li>\n  <li><a href="141B/index.html">Stats 141B</a>: Data & Web Technologies for Data Analysis</li>\n  <li><a href="https://github.com/jsharpna/DavisSML/">Stats 208</a>: Statistical Machine Learning</li>\n</ol>\n\n<h3>Students</h3>\n<ol>\n  <li>Liwei Wu, PhD Student</li>\n  <li>Xiaoyue Li, PhD Student</li>\n  <li>Yujun Chen, Masters Student</li>\n  <li>Andrew Chin, Undergraduate Student</li>\n</ol>\n\n<h3>Professional Membership</h3>\n<ol>\n  <li>Institute of Mathematical Statistics</li>\n  <li>Bernoulli Society</li>\n  <li>IEEE, Signal Processing Society</li>\n</ol>\n\n<h3>Research</h3>\n\n<div class="pubsec section group">\n<div class="col span_half">\n  <a href="research/graphsignal.html"><img src="media/As_slide.png" type="application/pdf"></img></a>\n</div>\n<div class="col span_half">\n  <a href="research/graphsignal.html"><h4>Graph Structured Signal Processing</h4>\n  (6 publications)<br></a>\n  Traditional signal processing techniques such as wavelet denoising and kernel smoothing, implicitly assume that the domain is homogeneous.  Graph structure provides us with a more flexible framework for filters over heterogeneous media, social networks, or semantic information.\n</div>\n</div>\n\n<div class="pubsec section group">\n<div class="col span_half">\n  <a href="research/scan.html"><h4>Scan Statistics over Networks</h4>\n    (6 publications)<br></a>\n    We develop novel methodology for detecting faint signals in sensor networks and images.\n  In images we develop a precise asymptotic analysis for fast scanning tools based on convolutional feedforward neural nets.\n  In general graphs, we look at approximation algorithms for the generalized likelihood ratio test.\n</div>\n<div class="col span_half">\n  <a href="research/scan.html"><img width="60%" src="media/graphscan.png" type="application/pdf"></img></a>\n</div>\n</div>\n\n<div class="pubsec section gr ...

# %% [markdown]
# ### Web APIs
#
# An _application programming interface_ (API) is a set of functions and data structures for communicating with other software. For instance, whenever you use a Python package, you're using the API created by the package's developers.
#
# Web sites sometimes provide an API so that programmers can access content without web scraping. In a web API, each function has a different URL. Sometimes these functions/URLs are called _endpoints_. Arguments can be passed to the function by adding `?PARAMETER=`
#
# The most popular kind of web API is a _representational state transfer_ (REST) API. In a REST API, the server handles separate function calls independently of each other.
#
# We can call a function in a web API by making an HTTP request.

# %% [markdown]
# ### Example: iTunes Web API
#
# Apple provides a web API for getting information about media on iTunes, with documentation [here](https://affiliate.itunes.apple.com/resources/documentation/itunes-store-web-service-search-api/). There is only one function in the API:
#
# ```
# https://itunes.apple.com/search
# ```
#
# According to the documentation, a GET request to this URL searches for an artist.

# %% [markdown]
# Let's write a Python function that acts as a wrapper for the search function.

# %%
def search_itunes(term, country):
    response = requests.get("https://itunes.apple.com/search", params = {
        "term": term,
        "country": country
    })
    response.raise_for_status()
    
    # ...
    
    return response

# %%
response.text
# Out:
# '\n\n\n{\n "resultCount":50,\n "results": [\n{"wrapperType":"track", "kind":"song", "artistId":921917, "collectionId":991183728, "trackId":991184319, "artistName":"Bill Conti", "collectionName":"Rocky (Original Motion Picture Score)", "trackName":"Gonna Fly Now", "collectionCensoredName":"Rocky (Original Motion Picture Score)", "trackCensoredName":"Gonna Fly Now (Theme From \\"Rocky\\")", "artistViewUrl":"https://itunes.apple.com/us/artist/bill-conti/921917?uo=4", "collectionViewUrl":"https://itunes.apple.com/us/album/gonna-fly-now-theme-from-rocky/991183728?i=991184319&uo=4", "trackViewUrl":"https://itunes.apple.com/us/album/gonna-fly-now-theme-from-rocky/991183728?i=991184319&uo=4", \n"previewUrl":"https://audio-ssl.itunes.apple.com/apple-assets-us-std-000001/Music7/v4/78/f5/20/78f52024-5931-93be-6e0e-ed65e2088ce9/mzaf_3023930814535994088.plus.aac.p.m4a", "artworkUrl30":"http://is2.mzstatic.com/image/thumb/Music5/v4/8b/09/fb/8b09fb7f-de9b-1ee8-45c1-f7ace985f360/source/30x30bb.jpg", "artworkUrl60":"http://is2.mzstatic.com/image/thumb/Music5/v4/8b/09/fb/8b09fb7f-de9b-1ee8-45c1-f7ace985f360/source/60x60bb.jpg", "artworkUrl100":"http://is2.mzstatic.com/image/thumb/Music5/v4/8b/09/fb/8b09fb7f-de9b-1ee8-45c1-f7ace985f360/source/100x100bb.jpg", "collectionPrice":11.99, "trackPrice":1.29, "releaseDate":"1976-10-14T07:00:00Z", "collectionExplicitness":"notExplicit", "trackExplicitness":"notExplicit", "discCount":1, "discNumber":1, "trackCount":13, "trackNumber":1, "trackTimeMillis":167533, "country":"USA", "currency":"USD", "primaryGenreName":"Soundtrack", "isStreamable":false}, \n{"wrapperType":"track", "kind":"song", "artistId":481488005, "collectionId":581997130, "trackId":581997309, "artistName":"A$AP Rocky", "collectionName":"LONG.LIVE.A$AP (Deluxe Version)", "trackName":"F**kin\' Problems (feat. Drake, 2 Chainz & Kendrick Lamar)", "collectionCensoredName":"LONG.LIVE.A$AP (Deluxe Version)", "trackCensoredName":"F**kin\' Problems (feat. Drake, 2 Chainz & Kendrick Lamar)", "artistViewUrl":"https://itunes.apple.com/us/artist/a%24ap-rocky/481488005?uo=4", "collectionViewUrl":"https://itunes.apple.com/us/album/f-kin-problems-feat-drake-2-chainz-kendrick-lamar/581997130?i=581997309&uo=4", "trackViewUrl":"https://itunes.apple.com/us/album/f-kin-problems-feat-drake-2-chainz-kendrick-lamar/581997130?i=581997309&uo=4", \n"previewUrl":"https://audio-ssl.itunes.apple.com/apple-assets-us-std-000001/Music/v4/13/a0/00/13a000ce-9102-5294-2f8f-96af412adb74/mzaf_7237758682353578925.plus.aac.p.m4a", "artworkUrl30":"http://is2.mzstatic.com/image/thumb/Music/v4/85/5a/a6/855aa69e-27b7-64c7-de55-5816814c7149/source/30x30bb.jpg", "artworkUrl60":"http://is2.mzstatic.com/image/thumb/Music/v4/85/5a/a6/855aa69e-27b7-64c7-de55-5816814c7149/source/60x60bb.jpg", "artworkUrl100":"http://is2.mzstatic.com/image/thumb/Music/v4/85/5a/a6/855aa69e-27b7-64c7-de55-5816814c7149/source/100x100bb.jpg", "collectionPrice":11.99, "trackPrice":1.29, "releaseDate":"2013-01-11T08:00:00Z", "collectionExplicitness":"explicit", "trackExplicitness":"explicit", "discCount":1, "discNumber":1, "trackCount":16, "trackNumber":7, "trackTimeMillis":233787, "country":"USA", "currency":"USD", "primaryGenreName":"Hip-Hop/Rap", "contentAdvisoryRating":"Explicit", "isStreamable":true}, \n{"wrapperType":"track", "kind":"song", "artistId":3713599, "collectionId":207443884, "trackId":207445080, "artistName":"Survivor", "collectionName":"Rocky IV (Original Motion Picture Soundtrack)", "trackName":"Eye of the Tiger", "collectionCensoredName":"Rocky IV (Original Motion Picture Soundtrack)", "trackCensoredName":"Eye of the Tiger", "collectionArtistId":885401, "collectionArtistName":"Various Artists", "artistViewUrl":"https://itunes.apple.com/us/artist/survivor/3713599?uo=4", "collectionViewUrl":"https://itunes.apple.com/us/album/eye-of-the-tiger/207443884?i=207445080&uo=4", "trackViewUrl":"https://itunes.apple.com/us/album/eye-of-the-tiger/207443884?i=207445080&uo=4", \n"previewUrl":"https://audio-s ...

# %%
x = response.json()

# %%
x.keys()
# Out:
# dict_keys(['resultCount', 'results'])

# %%
{"hello": 41, "goodbye": 32}.keys()
# Out:
# dict_keys(['hello', 'goodbye'])

# %% [markdown]
# Most of the time, it's a good strategy to "wrap" each web API fuction with a Python function. This lets you to use the web API as if it's just another Python module.
#
# If you're using the web API to get data, the next step is to convert the data to a Pandas data frame:

# %%
import pandas as pd

pd.DataFrame(x["results"])
# Out:
#        artistId                      artistName  \
# 0      921917.0                      Bill Conti
# 1   481488005.0                      A$AP Rocky
# 2     3713599.0                        Survivor
# 3   481488005.0                      A$AP Rocky
# 4           NaN  Akiva Schaffer & Jorma Taccone
# 5   481488005.0                      A$AP Rocky
# 6           NaN                John G. Avildsen
# 7           NaN                   Rick Famuyiwa
# 8   481488005.0                      A$AP Rocky
# 9   481488005.0                      A$AP Rocky
# 10  481488005.0                      A$AP Rocky
# 11  481488005.0                      A$AP Rocky
# 12  481488005.0                      A$AP Rocky
# 13  481488005.0                      A$AP Rocky
# 14  481488005.0                      A$AP Rocky
# 15  481488005.0                      A$AP Rocky
# 16  481488005.0                      A$AP Rocky
# 17  481488005.0                      A$AP Rocky
# 18  481488005.0                      A$AP Rocky
# 19  481488005.0                      A$AP Rocky
# 20  481488005.0                      A$AP Rocky
# 21  481488005.0                      A$AP Rocky
# 22  481488005.0                      A$AP Rocky
# 23  481488005.0                      A$AP Rocky
# 24  481488005.0                      A$AP Rocky
# 25  481488005.0                      A$AP Rocky
# 26  481488005.0                      A$AP Rocky
# 27  481488005.0                      A$AP Rocky
# 28  481488005.0                      A$AP Rocky
# 29  481488005.0                      A$AP Rocky
# 30  481488005.0                      A$AP Rocky
# 31  481488005.0                      A$AP Rocky
# 32  481488005.0                      A$AP Rocky
# 33  481488005.0                      A$AP Rocky
# 34  481488005.0                      A$AP Rocky
# 35  481488005.0                      A$AP Rocky
# 36  481488005.0                      A$AP Rocky
# 37  481488005.0                      A$AP Rocky
# 38  481488005.0                      A$AP Rocky
# 39  481488005.0                      A$AP Rocky
# 40  481488005.0                      A$AP Rocky
# 41  481488005.0                      A$AP Rocky
# 42  481488005.0                      A$AP Rocky
# 43  481488005.0                      A$AP Rocky
# 44  481488005.0                      A$AP Rocky
# 45  481488005.0                      A$AP Rocky
# 46  481488005.0                      A$AP Rocky
# 47  481488005.0                      A$AP Rocky
# 48  481488005.0                      A$AP Rocky
# 49  481488005.0                      A$AP Rocky
#
#                                         artistViewUrl  \
# 0   https://itunes.apple.com/us/artist/bill-conti/...
# 1   https://itunes.apple.com/us/artist/a%24ap-rock...
# 2   https://itunes.apple.com/us/artist/survivor/37...
# 3   https://itunes.apple.com/us/artist/a%24ap-rock...
# 4                                                 NaN
# 5   https://itunes.apple.com/us/artist/a%24ap-rock...
# 6                                                 NaN
# 7                                                 NaN
# 8   https://itunes.apple.com/us/artist/a%24ap-rock...
# 9   https://itunes.apple.com/us/artist/a%24ap-rock...
# 10  https://itunes.apple.com/us/artist/a%24ap-rock...
# 11  https://itunes.apple.com/us/artist/a%24ap-rock...
# 12  https://itunes.apple.com/us/artist/a%24ap-rock...
# 13  https://itunes.apple.com/us/artist/a%24ap-rock...
# 14  https://itunes.apple.com/us/artist/a%24ap-rock...
# 15  https://itunes.apple.com/us/artist/a%24ap-rock...
# 16  https://itunes.apple.com/us/artist/a%24ap-rock...
# 17  https://itunes.apple.com/us/artist/a%24ap-rock...
# 18  https://itunes.apple.com/us/artist/a%24ap-rock...
# 19  https://itunes.apple.com/us/artist/a%24ap-rock...
# 20  https://itunes.apple.com/us/artist/a%24ap-rock...
# 21  https://itunes.apple.com/us/artist/a%24ap-rock...
# 22  https://itunes.apple.com/us/artist/a%24ap-rock...
# 23  https://itunes.apple.com/us/artist/a%24ap-rock...
# 24  https://itunes.apple.com/us/artist/a%24ap-rock...
# 25  https://itunes.apple.com/us/artist/a%24ap-rock...
# 26  https://itunes.apple.com/us/artist/a%24ap-rock...
# 27  https://itunes.apple.com/us/artist/a%24ap-rock...
# 28  https://itunes.apple.com/us/artist/a%24ap-rock...
# 29  https://itunes.apple.com/us/artist/a%24ap-rock...
# 30  https://itunes.apple.com/us/artist/a%24ap-rock...
# 31  https://itunes.apple.com/us/artist/a%24ap-rock...
# 32  https://itunes.apple.com/us/artist/a%24ap-rock...
# 33  https://itunes.apple.com/us/artist/a%24ap-rock...
# 34  https://itunes.apple.com/us/artist/a%24ap-rock...
# 35  https://itunes.apple.com/us/artist/a%24ap-rock...
# 36  https://itunes.apple.com/us/artist/a%24ap-rock...
# 37  https://itunes.apple.com/us/artist/a%24ap-rock...
# 38  https://itunes.apple.com/us/artist/a%24ap-rock...
# 39  https://itunes.apple.com/us/artist/a%24ap-rock...
# 40  https://itunes.apple.com/us/artist/a%24ap-rock...
# 41  https://itunes.apple.com/us/artist/a%24ap-rock...
# 42  https://itunes.apple.com/us/artist/a%24ap-rock...
# 43  https://itunes.apple.com/us/artist/a%24ap-rock...
# 44  https://itunes.apple.com/us/artist/a%24ap-rock...
# 45  https://itunes.apple.com/us/artist/a%24ap-rock...
# 46  https://itunes.apple.com/us/artist/a%24ap-rock...
# 47  https://itunes.apple.com/us/artist/a%24ap-rock...
# 48  https://itunes.apple.com/us/artist/a%24ap-rock...
# 49  https://itunes.apple.com/us/artist/a%24ap-rock...
#
#                                         artworkUrl100  \
# 0   http://is2.mzstatic.com/image/thumb/Music5/v4/...
# 1   http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 2   http://is3.mzstatic.com/image/thumb/Music/v4/d...
# 3   http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 4   http://is5.mzstatic.com/image/thumb/Video20/v4...
# 5   http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 6   http://is4.mzstatic.com/image/thumb/Video69/v4...
# 7   http://is3.mzstatic.com/image/thumb/Video2/v4/...
# 8   http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 9   http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 10  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 11  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 12  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 13  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 14  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 15  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 16  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 17  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 18  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 19  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 20  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 21  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 22  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 23  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 24  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 25  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 26  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 27  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 28  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 29  http://is4.mzstatic.com/image/thumb/Music/v4/7...
# 30  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 31  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 32  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 33  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 34  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 35  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 36  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 37  http://is4.mzstatic.com/image/thumb/Music/v4/2...
# 38  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 39  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 40  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 41  http://is2.mzstatic.com/image/thumb/Music7/v4/...
# 42  http://is1.mzstatic.com/image/thumb/Music3/v4/...
# 43  http://is4.mzstatic.com/image/thumb/Music/v4/6...
# 44  http://is5.mzstatic.com/image/thumb/Music/v4/6...
# 45  http://is2.mzstatic.com/image/thumb/Music7/v4/...
# 46  http://is5.mzstatic.com/image/thumb/Music/v4/6...
# 47  http://is5.mzstatic.com/image/thumb/Music/v4/7...
# 48  http://is5.mzstatic.com/image/thumb/Music/v4/6...
# 49  http://is5.mzstatic.com/image/thumb/Music/v4/6...
#
#                                          artworkUrl30  \
# 0   http://is2.mzstatic.com/image/thumb/Music5/v4/...
# 1   http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 2   http://is3.mzstatic.com/image/thumb/Music/v4/d...
# 3   http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 4   http://is5.mzstatic.com/image/thumb/Video20/v4...
# 5   http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 6   http://is4.mzstatic.com/image/thumb/Video69/v4...
# 7   http://is3.mzstatic.com/image/thumb/Video2/v4/...
# 8   http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 9   http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 10  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 11  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 12  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 13  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 14  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 15  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 16  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 17  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 18  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 19  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 20  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 21  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 22  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 23  http://is2.mzstatic.com/image/thumb/Music/v4/8...
# 24  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 25  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 26  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 27  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 28  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 29  http://is4.mzstatic.com/image/thumb/Music/v4/7...
# 30  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 31  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 32  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 33  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 34  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 35  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 36  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 37  http://is4.mzstatic.com/image/thumb/Music/v4/2...
# 38  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 39  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 40  http://is2.mzstatic.com/image/thumb/Music1/v4/...
# 41  http://is2.mzstatic.com/image/thumb/Music7/v4/...
# 42  http://is1.mzstatic.com/image/thumb/Music3/v4/...
# 43  http://is4.mzstatic.com/image/thumb/Music/v4/6...
# 44  http://is5.mzstatic.com/image/thumb/Music/v4/6...
# 45  http://is2.mzstatic.com/image/thumb/Music7/v4/...
# 46  http://is5.mzstatic.com/image/thumb/Music/v4/6...
# 47  http://is5.mzstatic.com/image/thumb/Music/v4/7...
# 48  http://is5.mzstatic.com/image/thumb/Music/v4/6...
# 49  http://is5.mzstatic.com/image/thumb/Music/v4/6...
#
#                                          artworkUrl60  collectionArtistId  \
# 0   http://is2.mzstatic.com/image/thumb/Music5/v4/...                 NaN
# 1   http://is2.mzstatic.com/image/thumb/Music/v4/8...                 NaN
# 2   http://is3.mzstatic.com/image/thumb/Music/v4/d...            885401.0
# 3   http://is2.mzstatic.com/image/thumb/Music/v4/8...                 NaN
# 4   http://is5.mzstatic.com/image/thumb/Video20/v4...                 NaN
# 5   http://is2.mzstatic.com/image/thumb/Music/v4/8...                 NaN
# 6   http://is4.mzstatic.com/image/thumb/Video69/v4...          84755883.0
# 7   http://is3.mzstatic.com/image/thumb/Video2/v4/...                 NaN
# 8   http://is2.mzstatic.com/image/thumb/Music/v4/8...                 NaN
# 9   http://is2.mzstatic.com/image/thumb/Music1/v4/...                 NaN
# 10  http://is2.mzstatic.com/image/thumb/Music/v4/8...                 NaN
# 11  http://is2.mzstatic.com/image/thumb/Music/v4/8...                 NaN
# 12  http://is2.mzstatic.com/image/thumb/Music/v4/8...                 NaN
# 13  http://is2.mzstatic.com/image/thumb/Music1/v4/...                 NaN
# 14  http://is2.mzstatic.com/image/thumb/Music/v4/8...                 NaN
# 15  http://is2.mzstatic.com/image/thumb/Music/v4/8...                 NaN
# 16  http://is2.mzstatic.com/image/thumb/Music/v4/8...                 NaN
# 17  http://is2.mzstatic.com/image/thumb/Music/v4/8...                 NaN
# 18  http://is2.mzstatic.com/image/thumb/Music1/v4/...                 NaN
# 19  http://is2.mzstatic.com/image/thumb/Music/v4/8...                 NaN
# 20  http://is2.mzstatic.com/image/thumb/Music/v4/8...                 NaN
# 21  http://is2.mzstatic.com/image/thumb/Music/v4/8...                 NaN
# 22  http://is2.mzstatic.com/image/thumb/Music/v4/8...                 NaN
# 23  http://is2.mzstatic.com/image/thumb/Music/v4/8...                 NaN
# 24  http://is2.mzstatic.com/image/thumb/Music1/v4/...                 NaN
# 25  http://is2.mzstatic.com/image/thumb/Music1/v4/...                 NaN
# 26  http://is2.mzstatic.com/image/thumb/Music1/v4/...                 NaN
# 27  http://is2.mzstatic.com/image/thumb/Music1/v4/...                 NaN
# 28  http://is2.mzstatic.com/image/thumb/Music1/v4/...                 NaN
# 29  http://is4.mzstatic.com/image/thumb/Music/v4/7...                 NaN
# 30  http://is2.mzstatic.com/image/thumb/Music1/v4/...                 NaN
# 31  http://is2.mzstatic.com/image/thumb/Music1/v4/...                 NaN
# 32  http://is2.mzstatic.com/image/thumb/Music1/v4/...                 NaN
# 33  http://is2.mzstatic.com/image/thumb/Music1/v4/...                 NaN
# 34  http://is2.mzstatic.com/image/thumb/Music1/v4/...                 NaN
# 35  http://is2.mzstatic.com/image/thumb/Music1/v4/...                 NaN
# 36  http://is2.mzstatic.com/image/thumb/Music1/v4/...                 NaN
# 37  http://is4.mzstatic.com/image/thumb/Music/v4/2...                 NaN
# 38  http://is2.mzstatic.com/image/thumb/Music1/v4/...                 NaN
# 39  http://is2.mzstatic.com/image/thumb/Music1/v4/...                 NaN
# 40  http://is2.mzstatic.com/image/thumb/Music1/v4/...                 NaN
# 41  http://is2.mzstatic.com/image/thumb/Music7/v4/...                 NaN
# 42  http://is1.mzstatic.com/image/thumb/Music3/v4/...                 NaN
# 43  http://is4.mzstatic.com/image/thumb/Music/v4/6...          92345680.0
# 44  http://is5.mzstatic.com/image/thumb/Music/v4/6...                 NaN
# 45  http://is2.mzstatic.com/image/thumb/Music7/v4/...                 NaN
# 46  http://is5.mzstatic.com/image/thumb/Music/v4/6...                 NaN
# 47  http://is5.mzstatic.com/image/thumb/Music/v4/7...             36270.0
# 48  http://is5.mzstatic.com/image/thumb/Music/v4/6...                 NaN
# 49  http://is5.mzstatic.com/image/thumb/Music/v4/6...                 NaN
#
#    collectionArtistName                            collectionArtistViewUrl  \
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# 2       Various Artists                                                NaN
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
# 5                   NaN                                                NaN
# 6                   NaN  https://itunes.apple.com/us/artist/mgm/8475588...
# 7                   NaN                                                NaN
# 8                   NaN                                                NaN
# 9                   NaN                                                NaN
# 10                  NaN                                                NaN
# 11                  NaN                                                NaN
# 12                  NaN                                                NaN
# 13                  NaN                                                NaN
# 14                  NaN                                                NaN
# 15                  NaN                                                NaN
# 16                  NaN                                                NaN
# 17                  NaN                                                NaN
# 18                  NaN                                                NaN
# 19                  NaN                                                NaN
# 20                  NaN                                                NaN
# 21                  NaN                                                NaN
# 22                  NaN                                                NaN
# 23                  NaN                                                NaN
# 24                  NaN                                                NaN
# 25                  NaN                                                NaN
# 26                  NaN                                                NaN
# 27                  NaN                                                NaN
# 28                  NaN                                                NaN
# 29                  NaN                                                NaN
# 30                  NaN                                                NaN
# 31                  NaN                                                NaN
# 32                  NaN                                                NaN
# 33                  NaN                                                NaN
# 34                  NaN                                                NaN
# 35                  NaN                                                NaN
# 36                  NaN                                                NaN
# 37                  NaN                                                NaN
# 38                  NaN                                                NaN
# 39                  NaN                                                NaN
# 40                  NaN                                                NaN
# 41                  NaN                                                NaN
# 42                  NaN                                                NaN
# 43      Various Artists                                                NaN
# 44                  NaN                                                NaN
# 45                  NaN                                                NaN
# 46                  NaN                                                NaN
# 47      Various Artists                                                NaN
# 48                  NaN                                                NaN
# 49                  NaN                                                NaN
#
#                                collectionCensoredName     ...       \
# 0               Rocky (Original Motion Picture Score)     ...
# 1                     LONG.LIVE.A$AP (Deluxe Version)     ...
# 2       Rocky IV (Original Motion Picture Soundtrack)     ...
# 3                     LONG.LIVE.A$AP (Deluxe Version)     ...
# 4                                                 NaN     ...
# 5                     LONG.LIVE.A$AP (Deluxe Version)     ...
# 6                        Rocky Heavyweight Collection     ...
# 7                                                 NaN     ...
# 8                     LONG.LIVE.A$AP (Deluxe Version)     ...
# 9                                   AT.LONG.LAST.A$AP     ...
# 10                    LONG.LIVE.A$AP (Deluxe Version)     ...
# 11                    LONG.LIVE.A$AP (Deluxe Version)     ...
# 12                    LONG.LIVE.A$AP (Deluxe Version)     ...
# 13                                  AT.LONG.LAST.A$AP     ...
# 14                    LONG.LIVE.A$AP (Deluxe Version)     ...
# 15                    LONG.LIVE.A$AP (Deluxe Version)     ...
# 16                    LONG.LIVE.A$AP (Deluxe Version)     ...
# 17                    LONG.LIVE.A$AP (Deluxe Version)     ...
# 18                                  AT.LONG.LAST.A$AP     ...
# 19                    LONG.LIVE.A$AP (Deluxe Version)     ...
# 20                    LONG.LIVE.A$AP (Deluxe Version)     ...
# 21                    LONG.LIVE.A$AP (Deluxe Version)     ...
# 22                    LONG.LIVE.A$AP (Deluxe Version)     ...
# 23                    LONG.LIVE.A$AP (Deluxe Version)     ...
# 24                                  AT.LONG.LAST.A$AP     ...
# 25                                  AT.LONG.LAST.A$AP     ...
# 26                                  AT.LONG.LAST.A$AP     ...
# 27                                  AT.LONG.LAST.A$AP     ...
# 28                                  AT.LONG.LAST.A$AP     ...
# 29                                      Peso - Single     ...
# 30                                  AT.LONG.LAST.A$AP     ...
# 31                                  AT.LONG.LAST.A$AP     ...
# 32                                  AT.LONG.LAST.A$AP     ...
# 33                                  AT.LONG.LAST.A$AP     ...
# 34                                  AT.LONG.LAST.A$AP     ...
# 35                                  AT.LONG.LAST.A$AP     ...
# 36                                  AT.LONG.LAST.A$AP     ...
# 37                               Purple Swag - Single     ...
# 38                                  AT.LONG.LAST.A$AP     ...
# 39                                  AT.LONG.LAST.A$AP     ...
# 40                                  AT.LONG.LAST.A$AP     ...
# 41                                     LONG.LIVE.A$AP     ...
# 42                  Multiply (feat. Juicy J) - Single     ...
# 43                    The Music of Grand Theft Auto V     ...
# 44                                     LONG.LIVE.A$AP     ...
# 45                                     LONG.LIVE.A$AP     ...
# 46                                     LONG.LIVE.A$AP     ...
# 47  Divergent (Original Motion Picture Soundtrack)...     ...
# 48                                     LONG.LIVE.A$AP     ...
# 49                                     LONG.LIVE.A$AP     ...
#
#    trackHdPrice  trackHdRentalPrice     trackId  \
# 0           NaN                 NaN   991184319
# 1           NaN                 NaN   581997309
# 2           NaN                 NaN   207445080
# 3           NaN                 NaN   581997310
# 4         14.99                 NaN  1113248686
# 5           NaN                 NaN   581997270
# 6         14.99                3.99   219214592
# 7         14.99                3.99   999573394
# 8           NaN                 NaN   581997146
# 9           NaN                 NaN   994727382
# 10          NaN                 NaN   581997380
# 11          NaN                 NaN   581997470
# 12          NaN                 NaN   581997348
# 13          NaN                 NaN   994727309
# 14          NaN                 NaN   581997275
# 15          NaN                 NaN   581997385
# 16          NaN                 NaN   581997483
# 17          NaN                 NaN   581997474
# 18          NaN                 NaN   994727313
# 19          NaN                 NaN   581997280
# 20          NaN                 NaN   581997391
# 21          NaN                 NaN   581997387
# 22          NaN                 NaN   581997282
# 23          NaN                 NaN   581997283
# 24          NaN                 NaN   994727312
# 25          NaN                 NaN   994727303
# 26          NaN                 NaN   994727310
# 27          NaN                 NaN   994727377
# 28          NaN                 NaN   994727380
# 29          NaN                 NaN   481488008
# 30          NaN                 NaN   994727473
# 31          NaN                 NaN   994727308
# 32          NaN                 NaN   994727291
# 33          NaN                 NaN   994727376
# 34          NaN                 NaN   994727375
# 35          NaN                 NaN   994727314
# 36          NaN                 NaN   994727311
# 37          NaN                 NaN   486923597
# 38          NaN                 NaN   994727379
# 39          NaN                 NaN   994727381
# 40          NaN                 NaN   994727378
# 41          NaN                 NaN   582001752
# 42          NaN                 NaN   925503620
# 43          NaN                 NaN   712611057
# 44          NaN                 NaN   581997286
# 45          NaN                 NaN   582001753
# 46          NaN                 NaN   581997311
# 47          NaN                 NaN   826164363
# 48          NaN                 NaN   581997145
# 49          NaN                 NaN   581997384
#
#                                             trackName  trackNumber trackPrice  \
# 0                                       Gonna Fly Now          1.0       1.29
# 1   F**kin' Problems (feat. Drake, 2 Chainz & Kend...          7.0       1.29
# 2                                    Eye of the Tiger          4.0       1.29
# 3   Wild for the Night (feat. Skrillex & Birdy Nam...          8.0       1.29
# 4                  Popstar: Never Stop Never Stopping          NaN       9.99
# 5                                              Goldie          2.0       1.29
# 6                                               Rocky          1.0      14.99
# 7                                                Dope          NaN       9.99
# 8                                      Long Live a$AP          1.0       1.29
# 9   Everyday (feat. Rod Stewart x Miguel x Mark Ro...         17.0       1.29
# 10                                      Fashion Killa         10.0       1.29
# 11        Ghetto Symphony (feat. Gunplay & a$AP Ferg)         14.0       1.29
# 12  1Train (feat. Kendrick Lamar, Joey Badass, Yel...          9.0       1.29
# 13                                                L$D          4.0       1.29
# 14        PMW (All I Really Need) [feat. Schoolboy Q]          3.0       1.29
# 15                                            Phoenix         11.0       1.29
# 16                I Come Apart (feat. Florence Welch)         16.0       1.29
# 17                                             Angels         15.0       1.29
# 18                  Electric Body (feat. ScHoolboy Q)          8.0       1.29
# 19                                                Lvl          4.0       1.29
# 20                                              Jodye         13.0       1.29
# 21                                           Suddenly         12.0       1.29
# 22                             Hell (feat. Santigold)          5.0       1.29
# 23                               Pain (feat. Overdoz)          6.0       1.29
# 24                 Lord Pretty Flacko Jodye 2 (LPFJ2)          7.0       1.29
# 25                            Canal St. (feat. Bones)          2.0       1.29
# 26                                          Excuse Me          5.0       1.29
# 27                     Wavybone (feat. Juicy J x UGK)         12.0       1.29
# 28                              M'$ (feat. Lil Wayne)         15.0       1.29
# 29                                               Peso          1.0       1.29
# 30                  Back Home (feat. Mos Def x Acyde)         18.0       1.29
# 31       Fine Whine (feat. Joe Fox x Future x M.I.A.)          3.0       1.29
# 32                         Holy Ghost (feat. Joe Fox)          1.0       1.29
# 33                           Pharsyde (feat. Joe Fox)         11.0       1.29
# 34                              Max B (feat. Joe Fox)         10.0       1.29
# 35        Jukebox Joints (feat. Joe Fox x Kanye West)          9.0       1.29
# 36                                                 JD          6.0       1.29
# 37                                        Purple Swag          1.0       1.29
# 38                                      Better Things         14.0       1.29
# 39                                 Dreams (Interlude)         16.0       1.29
# 40         West Side Highway (feat. James Fauntleroy)         13.0       1.29
# 41  F**kin' Problems (feat. Drake, 2 Chainz & Kend...          7.0       1.29
# 42                           Multiply (feat. Juicy J)          1.0       1.29
# 43                                           r - Cali         12.0       0.99
# 44  F**kin' Problems (feat. Drake, 2 Chainz & Kend...          7.0       1.29
# 45  Wild For the Night (feat. Skrillex & Birdy Nam...          8.0       1.29
# 46  Wild For the Night (feat. Skrillex & Birdy Nam...          8.0       1.29
# 47                  In Distress (feat. Gesaffelstein)          9.0      -1.00
# 48                                     Long Live a$AP          1.0       1.29
# 49                                      Fashion Killa         10.0       1.29
#
#    trackRentalPrice trackTimeMillis  \
# 0               NaN          167533
# 1               NaN          233787
# 2               NaN          245640
# 3               NaN          212640
# 4               NaN         5190495
# 5               NaN          192067
# 6              3.99         7179928
# 7              3.99         6193280
# 8               NaN          289587
# 9               NaN          260991
# 10              NaN          236280
# 11              NaN          237733
# 12              NaN          372173
# 13              NaN          238314
# 14              NaN          234773
# 15              NaN          233880
# 16              NaN          217947
# 17              NaN          227080
# 18              NaN          255252
# 19              NaN          220133
# 20              NaN          260760
# 21              NaN          270707
# 22              NaN          231787
# 23              NaN          233267
# 24              NaN          126962
# 25              NaN          227431
# 26              NaN          238052
# 27              NaN          303006
# 28              NaN          233401
# 29              NaN          170307
# 30              NaN          278083
# 31              NaN          218542
# 32              NaN          191203
# 33              NaN          222329
# 34              NaN          241135
# 35              NaN          323962
# 36              NaN          105823
# 37              NaN          118560
# 38              NaN          199465
# 39              NaN          136768
# 40              NaN          176907
# 41              NaN          233667
# 42              NaN          223053
# 43              NaN          139707
# 44              NaN          233787
# 45              NaN          212680
# 46              NaN          212640
# 47              NaN          189176
# 48              NaN          289587
# 49              NaN          236280
#
#                                          trackViewUrl  wrapperType
# 0   https://itunes.apple.com/us/album/gonna-fly-no...        track
# 1   https://itunes.apple.com/us/album/f-kin-proble...        track
# 2   https://itunes.apple.com/us/album/eye-of-the-t...        track
# 3   https://itunes.apple.com/us/album/wild-for-the...        track
# 4   https://itunes.apple.com/us/movie/popstar-neve...        track
# 5   https://itunes.apple.com/us/album/goldie/58199...        track
# 6   https://itunes.apple.com/us/movie/rocky/id2192...        track
# 7   https://itunes.apple.com/us/movie/dope/id99957...        track
# 8   https://itunes.apple.com/us/album/long-live-a%...        track
# 9   https://itunes.apple.com/us/album/everyday-fea...        track
# 10  https://itunes.apple.com/us/album/fashion-kill...        track
# 11  https://itunes.apple.com/us/album/ghetto-symph...        track
# 12  https://itunes.apple.com/us/album/1train-feat-...        track
# 13  https://itunes.apple.com/us/album/l%24d/994727...        track
# 14  https://itunes.apple.com/us/album/pmw-all-i-re...        track
# 15  https://itunes.apple.com/us/album/phoenix/5819...        track
# 16  https://itunes.apple.com/us/album/i-come-apart...        track
# 17  https://itunes.apple.com/us/album/angels/58199...        track
# 18  https://itunes.apple.com/us/album/electric-bod...        track
# 19  https://itunes.apple.com/us/album/lvl/58199713...        track
# 20  https://itunes.apple.com/us/album/jodye/581997...        track
# 21  https://itunes.apple.com/us/album/suddenly/581...        track
# 22  https://itunes.apple.com/us/album/hell-feat-sa...        track
# 23  https://itunes.apple.com/us/album/pain-feat-ov...        track
# 24  https://itunes.apple.com/us/album/lord-pretty-...        track
# 25  https://itunes.apple.com/us/album/canal-st-fea...        track
# 26  https://itunes.apple.com/us/album/excuse-me/99...        track
# 27  https://itunes.apple.com/us/album/wavybone-fea...        track
# 28  https://itunes.apple.com/us/album/m%24-feat-li...        track
# 29  https://itunes.apple.com/us/album/peso/4814880...        track
# 30  https://itunes.apple.com/us/album/back-home-fe...        track
# 31  https://itunes.apple.com/us/album/fine-whine-f...        track
# 32  https://itunes.apple.com/us/album/holy-ghost-f...        track
# 33  https://itunes.apple.com/us/album/pharsyde-fea...        track
# 34  https://itunes.apple.com/us/album/max-b-feat-j...        track
# 35  https://itunes.apple.com/us/album/jukebox-join...        track
# 36  https://itunes.apple.com/us/album/jd/994727168...        track
# 37  https://itunes.apple.com/us/album/purple-swag/...        track
# 38  https://itunes.apple.com/us/album/better-thing...        track
# 39  https://itunes.apple.com/us/album/dreams-inter...        track
# 40  https://itunes.apple.com/us/album/west-side-hi...        track
# 41  https://itunes.apple.com/us/album/f-kin-proble...        track
# 42  https://itunes.apple.com/us/album/multiply-fea...        track
# 43  https://itunes.apple.com/us/album/r-cali/71261...        track
# 44  https://itunes.apple.com/us/album/f-kin-proble...        track
# 45  https://itunes.apple.com/us/album/wild-for-the...        track
# 46  https://itunes.apple.com/us/album/wild-for-the...        track
# 47  https://itunes.apple.com/us/album/in-distress-...        track
# 48  https://itunes.apple.com/us/album/long-live-a%...        track
# 49  https://itunes.apple.com/us/album/fashion-kill...        track
#
# [50 rows x 42 columns]

# %% [markdown]
# ### Being Polite

# %% [markdown]
# Slow down requests (in loops):

# %%
import time

for i in range(1000):
    response = requests.get("https://jsharpna.github.io/")
    time.sleep(0.5) # wait for 0.5 sec
    
# Generally you shouldn't make more than 20-30 requests / sec (based on Google's rules)

# %% [markdown]
# Avoid requesting things you've already requested:

# %%
import requests_cache # pip install requests_cache

requests_cache.install_cache("mycache")
